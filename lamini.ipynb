# %%
# %pip install lamini
from llama import LLMEngine
llm = LLMEngine(
    id="example_llm"
    config={"production.key": "<YOUR-KEY-HERE"}
)
# Out:
# ...
#
#   Obtaining dependency information for lamini from https://files.pythonhosted.org/packages/29/8e/5bae20abb4782fe92feef8d916f4b35dd88f369590070e010f9be757fd1a/lamini-0.0.21-2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for pydantic==1.10.* from https://files.pythonhosted.org/packages/e1/6b/6a68bd4f0837accdb78cf07e8590f2c9f00334003681b94d4957424248f2/pydantic-1.10.12-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/150.6 kB ? eta -:--:--
#      ------- ----------------------------- 30.7/150.6 kB 640.0 kB/s eta 0:00:01
#      ---------- -------------------------- 41.0/150.6 kB 487.6 kB/s eta 0:00:01
#      ---------------------- -------------- 92.2/150.6 kB 581.0 kB/s eta 0:00:01
#      -------------------------- --------- 112.6/150.6 kB 595.3 kB/s eta 0:00:01
#      ----------------------------- ------ 122.9/150.6 kB 554.9 kB/s eta 0:00:01
#      ------------------------------------ 150.6/150.6 kB 561.5 kB/s eta 0:00:00
# ...
